# %%
import json 
import requests
from pprint import pprint

# %%
token="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"
headers = {'Authorization': 'token ' + token}
url=f"https://api.github.com/search/repositories?q=created:>2022-05-01+archived:false&per_page=100"
repositories = requests.get(url,headers=headers).json()
print(repositories)
# Out:
# {'total_count': 11551507, 'incomplete_results': True, 'items': [{'id': 530536922, 'node_id': 'R_kgDOH59Z2g', 'name': 'amx', 'full_name': 'corsix/amx', 'private': False, 'owner': {'login': 'corsix', 'id': 1670, 'node_id': 'MDQ6VXNlcjE2NzA=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1670?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/corsix', 'html_url': 'https://github.com/corsix', 'followers_url': 'https://api.github.com/users/corsix/followers', 'following_url': 'https://api.github.com/users/corsix/following{/other_user}', 'gists_url': 'https://api.github.com/users/corsix/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/corsix/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/corsix/subscriptions', 'organizations_url': 'https://api.github.com/users/corsix/orgs', 'repos_url': 'https://api.github.com/users/corsix/repos', 'events_url': 'https://api.github.com/users/corsix/events{/privacy}', 'received_events_url': 'https://api.github.com/users/corsix/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/corsix/amx', 'description': 'Apple AMX Instruction Set', 'fork': False, 'url': 'https://api.github.com/repos/corsix/amx', 'forks_url': 'https://api.github.com/repos/corsix/amx/forks', 'keys_url': 'https://api.github.com/repos/corsix/amx/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/corsix/amx/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/corsix/amx/teams', 'hooks_url': 'https://api.github.com/repos/corsix/amx/hooks', 'issue_events_url': 'https://api.github.com/repos/corsix/amx/issues/events{/number}', 'events_url': 'https://api.github.com/repos/corsix/amx/events', 'assignees_url': 'https://api.github.com/repos/corsix/amx/assignees{/user}', 'branches_url': 'https://api.github.com/repos/corsix/amx/branches{/branch}', 'tags_url': 'https://api.github.com/repos/corsix/amx/tags', 'blobs_url': 'https://api.github.com/repos/corsix/amx/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/corsix/amx/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/corsix/amx/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/corsix/amx/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/corsix/amx/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/corsix/amx/languages', 'stargazers_url': 'https://api.github.com/repos/corsix/amx/stargazers', 'contributors_url': 'https://api.github.com/repos/corsix/amx/contributors', 'subscribers_url': 'https://api.github.com/repos/corsix/amx/subscribers', 'subscription_url': 'https://api.github.com/repos/corsix/amx/subscription', 'commits_url': 'https://api.github.com/repos/corsix/amx/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/corsix/amx/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/corsix/amx/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/corsix/amx/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/corsix/amx/contents/{+path}', 'compare_url': 'https://api.github.com/repos/corsix/amx/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/corsix/amx/merges', 'archive_url': 'https://api.github.com/repos/corsix/amx/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/corsix/amx/downloads', 'issues_url': 'https://api.github.com/repos/corsix/amx/issues{/number}', 'pulls_url': 'https://api.github.com/repos/corsix/amx/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/corsix/amx/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/corsix/amx/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/corsix/amx/labels{/name}', 'releases_url': 'https://api.github.com/repos/corsix/amx/releases{/id}', 'deployments_url': 'https://api.github.com/repos/corsix/amx/deployments', 'created_at': '2022-08-30T07:02:17Z', 'updated_at': '2023-05-03T11:01:23Z',  ...

# %%
pprint(len(repositories['items']))
# Out:
# 100

# %%
for i in range(100):
    repo_name=repositories['items'][i]['full_name']
    print(repo_name)
# Out:
# XSaintX/libroR-AnalisisDatos
# memester-xyz/solenv
# erc721k/monorepo
# shnela/python_course
# apple/ml-no-token-left-behind
# codeartx/awesome-algorithm
# greymd/mamadm
# sailay1996/SpoolTrigger
# NatanaelAntonioli/CaptainFrogTorrentFinder
# aqvaspirt/seoskillmap
# oslabs-beta/Neptune
# p0dalirius/MSSQL-Analysis-Coerce
# jfrog/text4shell-tools
# reuters-graphics/example_svelte-graph-patterns
# TumoiYorozu/white200
# zzhStrive/react-vite-admin
# Nevin1901/erlog
# TomasVotruba/awesome-php-ast
# ichitaro/terrain-warp
# chatbotgang/go-clean-arch
# fdisotto/esp32-mqtt-example
# 0xMisaka/MEV-from-LUNA-Collapse
# milooy/yurim-josh-wedding-card
# b03505036/UniInst
# pojntfx/htorrent
# Cryptocoders-wtf/assetstore-contract
# cranberryware/cranberry-punch
# flatz/ida_ps5_elf_plugin
# Tmitsuha/panel
# siddharthkp/css-out-js
# b0o/aws-favicons-webextension
# THHamiltonSmith/webdevhub
# Cat-Computing-Universe/PyLab
# peter-tharwat/countries
# jidiai/SummerCourse2022
# assetnote/jira-mobile-ssrf-exploit
# ernest19/Geospatial_Developers
# benlesh/rxooks
# MKhazamipour/wireguard-arvancloud
# alstn2468/2022-jsconf-presentation
# go-tk/vk8s
# ruesandora/teritori-testnet
# dorianim/money-balancer
# WuDuShanCheng/front-show
# tomriddle77/Hacktober22
# TylerMcCraw/compose-creations
# axic/evm.elf
# editso/gungnir
# fusionhuh/deskimg
# vnsmoreira/get-route
# kshitij12345/torchnnprofiler
# ergrelet/cpplumber
# borakasmer/fuel
# TheOfficialFloW/Presentations
# ekoby/mqziti
# nyph-infosec/daggerboard
# oslabs-beta/iris
# oslabs-beta/franzView
# staltz/ttosa
# shellward/StablenderDiffusion
# sheepla/longgopher
# rustcc/2022RustChinaCnf-ppts
# Crunchyman-ralph/shopify-app-node-monorepo-express-vite
# forbearing/k8s
# vueschool/vuejs-forge-the-project
# ericpd/mr.wifibrute
# gamename/raspberry-pi-iot-cat-doorbell
# eliben/go-sudoku
# Ramilito/kubediff
# WesleyHsieh0806/Downstair-Battle
# kokonior/Swift-Projects
# TencentARC/RepSR
# AkhilSharma90/node-ecommerce-V2
# gwenneg/flight-tracker-demo
# AnaralahBelore223/marcos-martial-law-library
# tts-tutorial/icassp2022
# jbkunst/klassets
# mllamazares/STRIDE-vs-ASVS
# first-phoenix/PlacementResources_by_Swaraj
# BexTuychiev/tricking-data-science
# ruesandora/CW20-ICS20-Smart-Contract
# GraphicDThanh/danang-cuisine
# oslabs-beta/parroteer
# mrtc0/seccamp-2022
# shuo-china/shuo-ui
# laisfrigerio/ja-escalou-seu-time-no-cartola-hoje
# matthewcieplak/er-99
# mintrocket/MintPermissions
# Sorangon/Level-Up-Sketch-Open-Project
# dontpanicdao/starknet-burner
# ardiri/palmos-liberty
# R0X4R/Agnee
# coolbutuseless/isocubes
# microsoft/Build2022-AI-examples
# laisfrigerio/copy-emoji-to-clipboard
# MDAnalysis/WorkshopMDMLEdinburgh2022
# instadeepai/catx
# storopoli/Julia-Workshop
# ultramsg/vbnet-whatsapp-chatbot
# blackjax-devs/sampling-book

# %%
print(repo_name)
spec_repo_url=requests.get(f"https://api.github.com/repos/{repo_name}/commits?per_page=1&page=1",headers=headers)
headers = spec_repo_url.headers
print(headers)
# # pprint(headers['Link'])
pprint(int(headers['Link'].split('&page=')[-1].split(';')[0].split('>')[0]))
# Out:
# blackjax-devs/sampling-book
# {'Server': 'GitHub.com', 'Date': 'Tue, 09 May 2023 15:56:26 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"297039dde2b25b59fea102b5df0bcc2207f1bd18238027c85901231d26eab6d3"', 'Last-Modified': 'Mon, 20 Feb 2023 15:45:22 GMT', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/repositories/581039832/commits?per_page=1&page=2>; rel="next", <https://api.github.com/repositories/581039832/commits?per_page=1&page=34>; rel="last"', 'x-github-api-version-selected': '2022-11-28', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '58', 'X-RateLimit-Reset': '1683650524', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '2', 'Accept-Ranges': 'bytes', 'Content-Length': '817', 'X-GitHub-Request-Id': 'A57E:2CC3:EA6880:EC093D:645A6D2A'}
# 34

# %%
headers = spec_repo_url.headers
pprint(headers['Link'])
pprint(int(headers['Link'].split('&page=')[-1].split(';')[0].split('>')[0]))
# Out:
# ('<https://api.github.com/repositories/581039832/commits?per_page=1&page=2>; '
#  'rel="next", '
#  '<https://api.github.com/repositories/581039832/commits?per_page=1&page=34>; '
#  'rel="last"')
# 34
