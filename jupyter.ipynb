# %%
import json 
import requests
from pprint import pprint

# %%
token="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"
headers = {'Authorization': 'token ' + token}
url=f"https://api.github.com/search/repositories?q=created:>2022-05-01+archived:false&per_page=100"
repositories = requests.get(url,headers=headers).json()
print(repositories)
# Out:
# {'total_count': 12438478, 'incomplete_results': True, 'items': [{'id': 502424220, 'node_id': 'R_kgDOHfJinA', 'name': 'svg-spinners', 'full_name': 'n3r4zzurr0/svg-spinners', 'private': False, 'owner': {'login': 'n3r4zzurr0', 'id': 15423974, 'node_id': 'MDQ6VXNlcjE1NDIzOTc0', 'avatar_url': 'https://avatars.githubusercontent.com/u/15423974?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/n3r4zzurr0', 'html_url': 'https://github.com/n3r4zzurr0', 'followers_url': 'https://api.github.com/users/n3r4zzurr0/followers', 'following_url': 'https://api.github.com/users/n3r4zzurr0/following{/other_user}', 'gists_url': 'https://api.github.com/users/n3r4zzurr0/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/n3r4zzurr0/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/n3r4zzurr0/subscriptions', 'organizations_url': 'https://api.github.com/users/n3r4zzurr0/orgs', 'repos_url': 'https://api.github.com/users/n3r4zzurr0/repos', 'events_url': 'https://api.github.com/users/n3r4zzurr0/events{/privacy}', 'received_events_url': 'https://api.github.com/users/n3r4zzurr0/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/n3r4zzurr0/svg-spinners', 'description': 'A collection of 24 x 24 dp SVG spinners! (CSS & SMIL)', 'fork': False, 'url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners', 'forks_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/forks', 'keys_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/teams', 'hooks_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/hooks', 'issue_events_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/issues/events{/number}', 'events_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/events', 'assignees_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/assignees{/user}', 'branches_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/branches{/branch}', 'tags_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/tags', 'blobs_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/languages', 'stargazers_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/stargazers', 'contributors_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/contributors', 'subscribers_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/subscribers', 'subscription_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/subscription', 'commits_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/contents/{+path}', 'compare_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/merges', 'archive_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/downloads', 'issues_url': 'https://api.github.com/repos/n3r4zzurr0/svg-spinners/issues{/number}', 'pulls_url': 'https://ap ...

# %%
pprint(len(repositories['items']))
type(repositories['items'][0])
# Out:
# 100
# dict

# %%
for i in range(100):
    repo_name=repositories['items'][i]['full_name']
    print(repo_name)
# Out:
# n3r4zzurr0/svg-spinners
# berthubert/googerteller
# NaiboWang/CommandlineConfig
# LearningOS/rust-based-os-comp2023
# midudev/kings-league-project
# bytedance/bitsail
# acikkaynak/afet-org
# bumble-tech/private-detector
# 7thSamurai/steganography
# kaleidawave/ezno
# OIRNOIR/WackyWebM
# DragoQCC/HardHatC2
# ockeghem/badtodo
# meodai/poline
# woodrush/lambda-8cc
# Jittor/JNeRF
# cremich/cdk-bill-bot
# podium/elixir-secure-coding
# 4DVLab/Vision-Centric-BEV-Perception
# patchy631/machine-learning
# USTC3DV/NDR-code
# aqueducthq/aqueduct
# KrauseFx/InAppBrowser.com
# PiotrNawrot/nanoT5
# dabit3/foundry-cheatsheet
# tweetback/tweetback
# deepinstinct/Dirty-Vanity
# MysticFoxDE/WINDOWS-OPTIMIZATIONS
# AammarTufail/pythonkachilla_version2
# NUL0x4C/AtomLdr
# Roaa94/recipes_ui_app
# komomon/CVE-2022-30190-follina-Office-MSDT-Fixed
# nettitude/SharpWSUS
# deepmind/tracr
# asweigart/humre
# PaddlePaddle/PaddleYOLO
# rksm/hot-lib-reloader-rs
# zegl/extremely-linear
# CyberSecurityUP/Red-Team-Management
# dn0m1n8tor/AndroidPentest101
# lecepin/douyin-downloader
# matter-labs/zksync-era
# liutikas/gradle-best-practices
# smy20011/dreambooth-gui
# AnasImloul/Leetcode-Solutions
# opendilab/DI-sheep
# chainguard-dev/ssc-reading-list
# liuliu/swift-diffusion
# apple/ml-gmpi
# gayolGate/gayolGate
# penberg/awesome-low-latency
# fzdwx/infinite
# milanm/azure-cheat-sheet
# devcontainers/templates
# the-full-stack/fsdl-text-recognizer-2022-labs
# NVIDIA-Omniverse/Orbit
# OpenMindClub/awesome-scholarly-productivity
# MrTornado24/Next3D
# mektigboy/evm-chad
# wolandark/wim
# rebuild-123/Python-Head-First-Design-Patterns
# cramppet/regulator
# Abacatinhos/eventos-tech-brasil
# milanm/Cloud-Product-Mapping
# wll8/lodash-utils
# yihong0618/blue
# peterhanania/Discord-Package
# supabase/wrappers
# daffainfo/match-replace-burp
# trpc/next-13
# pintariching/railwind
# Rocketseat/eslint-config-rocketseat
# VITA-Group/NeuralLift-360
# mandiant/STrace
# GPUOpen-Tools/radeon_raytracing_analyzer
# ketanthakurr/Three-Ticket-Please
# ketanthakurr/Hosting-WebProject
# wenet-e2e/WeTextProcessing
# sorbayhq/sorbay
# bananabr/TimeException
# zouyongzou/electron-forge-publisher-oss
# GraesonB/ChatGPT-Wrapper-For-Unity
# abuanwar072/Build-an-Animated-App-with-Rive-and-Flutter
# NordSecurity/nordvpn-linux
# MalwareApiLib/MalwareApiLibrary
# lucahammer/fedifinder
# CsEnox/CVE-2022-2992
# Aur0ra-m/APIKiller
# gamozolabs/mempeek
# nv-tlabs/vqad
# MaherAzzouzi/CVE-2022-37706-LPE-exploit
# mostafaznv/laracache
# bankisan/zkShield
# PayloadSecurity/Sandbox_Scryer
# kevinsblake/NatParksPalettes
# hmaverickadams/Windows-WiFi-Extractor
# sparshg/asteroids-genetic
# OpenRarity/open-rarity
# opendilab/awesome-exploration-rl
# woodrush/lambdalisp

# %%
print(repo_name)
spec_repo_url=requests.get(f"https://api.github.com/repos/{repo_name}/commits?per_page=1&page=1",headers=headers)
headers = spec_repo_url.headers
print(headers)
# # pprint(headers['Link'])
pprint(int(headers['Link'].split('&page=')[-1].split(';')[0].split('>')[0]))
# Out:
# CCob/PIVert
# {'Server': 'GitHub.com', 'Date': 'Thu, 11 May 2023 15:14:45 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Cache-Control': 'private, max-age=60, s-maxage=60', 'Vary': 'Accept, Authorization, Cookie, X-GitHub-OTP, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"01c758f962be5bc103672cdde137c443e492daaeca4756195f6d262cef886885"', 'Last-Modified': 'Thu, 25 Aug 2022 08:52:20 GMT', 'X-OAuth-Scopes': 'repo', 'X-Accepted-OAuth-Scopes': '', 'github-authentication-token-expiration': '2023-05-16 14:36:14 UTC', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/repositories/527626490/commits?per_page=1&page=2>; rel="next", <https://api.github.com/repositories/527626490/commits?per_page=1&page=5>; rel="last"', 'x-github-api-version-selected': '2022-11-28', 'X-RateLimit-Limit': '5000', 'X-RateLimit-Remaining': '4997', 'X-RateLimit-Reset': '1683819105', 'X-RateLimit-Used': '3', 'X-RateLimit-Resource': 'core', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-GitHub-Request-Id': 'DB48:7C7F:641390E:64FB4F7:645D0664'}
# 5

# %%
headers = spec_repo_url.headers
pprint(headers['Link'])
pprint(int(headers['Link'].split('&page=')[-1].split(';')[0].split('>')[0]))
# Out:
# ('<https://api.github.com/repositories/527626490/commits?per_page=1&page=2>; '
#  'rel="next", '
#  '<https://api.github.com/repositories/527626490/commits?per_page=1&page=5>; '
#  'rel="last"')
# 5

# %%
#manual test for a repo with a big number of commits >1000 to see if the trick for finding the commits doesnt have an upper limit of 1000
spec_repo_url=requests.get(f"https://api.github.com/repos/huggingface/transformers/commits?per_page=1&page=1",headers=headers)
headers = spec_repo_url.headers
pprint(headers['Link'])
pprint(int(headers['Link'].split('&page=')[-1].split(';')[0].split('>')[0]))
# Out:
# ('<https://api.github.com/repositories/155220641/commits?per_page=1&page=2>; '
#  'rel="next", '
#  '<https://api.github.com/repositories/155220641/commits?per_page=1&page=12863>; '
#  'rel="last"')
# 12863

# %%
spec_repo_contents=requests.get(f"https://api.github.com/repos/memester-xyz/solenv/contents",headers=headers).json()
for i in spec_repo_contents:
    if "test" in i['name'].lower():
        print('yes')
# Out:
# yes
# yes
