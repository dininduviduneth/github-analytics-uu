# %%
import json 
import requests
from pprint import pprint

# %%
token="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"
headers = {'Authorization': 'token ' + token}
url=f"https://api.github.com/search/repositories?q=created:>2022-05-01+archived:false&per_page=100"
repositories = requests.get(url,headers=headers).json()
print(repositories)
# Out:
# {'total_count': 11630100, 'incomplete_results': True, 'items': [{'id': 527234128, 'node_id': 'R_kgDOH2z0UA', 'name': 'Pico-10BASE-T', 'full_name': 'kingyoPiyo/Pico-10BASE-T', 'private': False, 'owner': {'login': 'kingyoPiyo', 'id': 8263942, 'node_id': 'MDQ6VXNlcjgyNjM5NDI=', 'avatar_url': 'https://avatars.githubusercontent.com/u/8263942?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/kingyoPiyo', 'html_url': 'https://github.com/kingyoPiyo', 'followers_url': 'https://api.github.com/users/kingyoPiyo/followers', 'following_url': 'https://api.github.com/users/kingyoPiyo/following{/other_user}', 'gists_url': 'https://api.github.com/users/kingyoPiyo/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/kingyoPiyo/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/kingyoPiyo/subscriptions', 'organizations_url': 'https://api.github.com/users/kingyoPiyo/orgs', 'repos_url': 'https://api.github.com/users/kingyoPiyo/repos', 'events_url': 'https://api.github.com/users/kingyoPiyo/events{/privacy}', 'received_events_url': 'https://api.github.com/users/kingyoPiyo/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/kingyoPiyo/Pico-10BASE-T', 'description': '10BASE-T from Raspberry Pi Pico', 'fork': False, 'url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T', 'forks_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/forks', 'keys_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/teams', 'hooks_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/hooks', 'issue_events_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/issues/events{/number}', 'events_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/events', 'assignees_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/assignees{/user}', 'branches_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/branches{/branch}', 'tags_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/tags', 'blobs_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/languages', 'stargazers_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/stargazers', 'contributors_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/contributors', 'subscribers_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/subscribers', 'subscription_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/subscription', 'commits_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/contents/{+path}', 'compare_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/merges', 'archive_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/downloads', 'issues_url': 'https://api.github.com/repos/kingyoPiyo/Pico-10BASE-T/issues{/number}', 'pulls_url': ' ...

# %%
pprint(len(repositories['items']))
# Out:
# 100

# %%
for i in range(100):
    repo_name=repositories['items'][i]['full_name']
    print(repo_name)
# Out:
# kingyoPiyo/Pico-10BASE-T
# DSchroer/dslcad
# XSaintX/libroR-AnalisisDatos
# rsms/llvmbox
# Mazamars312/Analogue_Pocket_Neogeo
# OmicsML/dance
# enricozb/intuitive
# lmxyy/sige
# arnabbiswas1/kaggle_pipeline_tps_aug_22
# odashi/davinci-functions
# HuolalaTech/HLLOfflineWebView-android
# malakhov-dmitrii/noizer-one_v2
# jamii/jams
# ADOOO/Joker
# thallo-io/ethers-js-cheatsheet
# heroku/roadmap
# bi1yeu/recruiter_rm
# keerthanpg/TalkToCode
# alexellis/run-job
# iyear/searchx
# hiAndrewQuinn/minimum-viable-hugo
# awsaaaq/GoBP
# deta/deta
# TorontoTechCommunity/CanadaJobSearch2023
# OldJii/free_check_box
# cdpred/RedTalaria
# ayin86/digitcube
# michael-rubel/laravel-value-objects
# erc721k/monorepo
# bitindi/blockchain-core
# mzelzoghbi/android-developer-roadmap
# mandiant/macos-UnifiedLogs
# spiritualized1997/openFPGA-SMS
# oslabs-beta/DacheQL
# yaakov123/hagana
# gh0x0st/wanderer
# chadcat7/kodo
# ip2k/I-Dont-Care-About-HSTS-For-Localhost
# BoLinJay/xiaochengxiaitian
# maxwellpeterson/kafka-worker
# apple/ml-no-token-left-behind
# igdev116/vite-react-ts-eslint-prettier
# sleirsgoevy/bd-jb
# sony/sqvae
# kochis/webgl-map
# Down-1998/x-ui
# foyer-work/Ooogle-it
# yuangh-x/2022-NIPS-Tenrec
# Luisnadachi/SQL4Noobs
# FlipperMaker/flippermaker.github.io
# stolk/energygraph
# ltratt/pizauth
# NatanaelAntonioli/CaptainFrogTorrentFinder
# dabit3/perma
# Zold1/linux-basics
# m-ou-se/auto-import
# mv-lab/AISP
# whwlsfb/SpringSpider
# fengres/mixvoxels
# webfansplz/temir-snake-game
# Vysp3r/ProtonPlus
# vinnyalvs/ListagemCertificadosGratuitos
# thundra-io/merloc-java
# ANSSI-FR/DFIR4vSphere
# steveruizok/liquorstore
# jfrog/text4shell-tools
# reuters-graphics/example_svelte-graph-patterns
# wangzmgit/leaf
# l-portet/svelte-switch-case
# nakdeyes/UnrealImGuiTools
# wwenhongich/LIO-FUSION
# anomic30/Storz
# zzhStrive/react-vite-admin
# viney-shih/go-cache
# IIC2133-PUC/2022-2
# Nevin1901/erlog
# Ryu0118/Kusa
# recmo/yul
# gladzhang/ART
# ichitaro/terrain-warp
# austintheriot/wrend
# liguge/Journals-of-Prognostics-and-Health-Management
# fdisotto/esp32-mqtt-example
# jackrusher/scimacs
# JulietLJY/MOOD
# smplbody/hmr-benchmarks
# awslabs/slapo
# MPLew-is/deep-codable
# Cr4ckC4t/cve-2022-41352-zimbra-rce
# 0xMisaka/MEV-from-LUNA-Collapse
# epitaque/dreambooth_depth2img
# milooy/yurim-josh-wedding-card
# fastai/execnb
# b03505036/UniInst
# advanceflow/Elisp
# zalky/cues
# pojntfx/htorrent
# Cryptocoders-wtf/assetstore-contract
# flatz/ida_ps5_elf_plugin
# CCob/PIVert

# %%
print(repo_name)
spec_repo_url=requests.get(f"https://api.github.com/repos/{repo_name}/commits?per_page=1&page=1",headers=headers)
headers = spec_repo_url.headers
print(headers)
# # pprint(headers['Link'])
pprint(int(headers['Link'].split('&page=')[-1].split(';')[0].split('>')[0]))
# Out:
# CCob/PIVert
# {'Server': 'GitHub.com', 'Date': 'Thu, 11 May 2023 15:14:45 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Cache-Control': 'private, max-age=60, s-maxage=60', 'Vary': 'Accept, Authorization, Cookie, X-GitHub-OTP, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"01c758f962be5bc103672cdde137c443e492daaeca4756195f6d262cef886885"', 'Last-Modified': 'Thu, 25 Aug 2022 08:52:20 GMT', 'X-OAuth-Scopes': 'repo', 'X-Accepted-OAuth-Scopes': '', 'github-authentication-token-expiration': '2023-05-16 14:36:14 UTC', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/repositories/527626490/commits?per_page=1&page=2>; rel="next", <https://api.github.com/repositories/527626490/commits?per_page=1&page=5>; rel="last"', 'x-github-api-version-selected': '2022-11-28', 'X-RateLimit-Limit': '5000', 'X-RateLimit-Remaining': '4997', 'X-RateLimit-Reset': '1683819105', 'X-RateLimit-Used': '3', 'X-RateLimit-Resource': 'core', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-GitHub-Request-Id': 'DB48:7C7F:641390E:64FB4F7:645D0664'}
# 5

# %%
headers = spec_repo_url.headers
pprint(headers['Link'])
pprint(int(headers['Link'].split('&page=')[-1].split(';')[0].split('>')[0]))
# Out:
# ('<https://api.github.com/repositories/527626490/commits?per_page=1&page=2>; '
#  'rel="next", '
#  '<https://api.github.com/repositories/527626490/commits?per_page=1&page=5>; '
#  'rel="last"')
# 5

# %%
spec_repo_url=requests.get(f"https://api.github.com/repos/memester-xyz/solenv/commits?per_page=1&page=1",headers=headers)
headers = spec_repo_url.headers
pprint(headers['Link'])
pprint(int(headers['Link'].split('&page=')[-1].split(';')[0].split('>')[0]))
# Out:
# ('<https://api.github.com/repositories/508444882/commits?per_page=1&page=2>; '
#  'rel="next", '
#  '<https://api.github.com/repositories/508444882/commits?per_page=1&page=36>; '
#  'rel="last"')
# 36

# %%
spec_repo_contents=requests.get(f"https://api.github.com/repos/memester-xyz/solenv/contents",headers=headers).json()
for i in spec_repo_contents:
    if "test" in i['name'].lower():
        print('yes')
# Out:
# yes
# yes
