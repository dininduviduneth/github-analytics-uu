# %%
import json 
import requests
from pprint import pprint

# %%
token="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"
headers = {'Authorization': 'token ' + token}
url=f"https://api.github.com/search/repositories?q=created:>2022-05-01+archived:false&per_page=100"
repositories = requests.get(url,headers=headers).json()
print(repositories)
# Out:
# {'total_count': 11003611, 'incomplete_results': True, 'items': [{'id': 523577677, 'node_id': 'R_kgDOHzUpTQ', 'name': 'libroR-AnalisisDatos', 'full_name': 'XSaintX/libroR-AnalisisDatos', 'private': False, 'owner': {'login': 'XSaintX', 'id': 34045810, 'node_id': 'MDQ6VXNlcjM0MDQ1ODEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/34045810?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/XSaintX', 'html_url': 'https://github.com/XSaintX', 'followers_url': 'https://api.github.com/users/XSaintX/followers', 'following_url': 'https://api.github.com/users/XSaintX/following{/other_user}', 'gists_url': 'https://api.github.com/users/XSaintX/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/XSaintX/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/XSaintX/subscriptions', 'organizations_url': 'https://api.github.com/users/XSaintX/orgs', 'repos_url': 'https://api.github.com/users/XSaintX/repos', 'events_url': 'https://api.github.com/users/XSaintX/events{/privacy}', 'received_events_url': 'https://api.github.com/users/XSaintX/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/XSaintX/libroR-AnalisisDatos', 'description': 'this project contains R code about analysing data from the book Analisis de datos con R', 'fork': False, 'url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos', 'forks_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/forks', 'keys_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/teams', 'hooks_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/hooks', 'issue_events_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/issues/events{/number}', 'events_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/events', 'assignees_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/assignees{/user}', 'branches_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/branches{/branch}', 'tags_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/tags', 'blobs_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/languages', 'stargazers_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/stargazers', 'contributors_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/contributors', 'subscribers_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/subscribers', 'subscription_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/subscription', 'commits_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/contents/{+path}', 'compare_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/merges', 'archive_url': 'https://api.github.com/repos/XSaintX/libroR-AnalisisDatos/{archive_format}{/ref}', 'downloads_url': 'https://api.gi ...

# %%
pprint(len(repositories['items']))
# Out:
# 100

# %%
for i in range(100):
    repo_name=repositories['items'][i]['full_name']
    print(repo_name)
# Out:
# XSaintX/libroR-AnalisisDatos
# memester-xyz/solenv
# erc721k/monorepo
# shnela/python_course
# apple/ml-no-token-left-behind
# codeartx/awesome-algorithm
# greymd/mamadm
# sailay1996/SpoolTrigger
# NatanaelAntonioli/CaptainFrogTorrentFinder
# aqvaspirt/seoskillmap
# oslabs-beta/Neptune
# p0dalirius/MSSQL-Analysis-Coerce
# jfrog/text4shell-tools
# reuters-graphics/example_svelte-graph-patterns
# TumoiYorozu/white200
# zzhStrive/react-vite-admin
# Nevin1901/erlog
# TomasVotruba/awesome-php-ast
# ichitaro/terrain-warp
# chatbotgang/go-clean-arch
# fdisotto/esp32-mqtt-example
# 0xMisaka/MEV-from-LUNA-Collapse
# milooy/yurim-josh-wedding-card
# b03505036/UniInst
# pojntfx/htorrent
# Cryptocoders-wtf/assetstore-contract
# cranberryware/cranberry-punch
# flatz/ida_ps5_elf_plugin
# Tmitsuha/panel
# siddharthkp/css-out-js
# b0o/aws-favicons-webextension
# THHamiltonSmith/webdevhub
# Cat-Computing-Universe/PyLab
# peter-tharwat/countries
# jidiai/SummerCourse2022
# assetnote/jira-mobile-ssrf-exploit
# ernest19/Geospatial_Developers
# benlesh/rxooks
# MKhazamipour/wireguard-arvancloud
# alstn2468/2022-jsconf-presentation
# go-tk/vk8s
# ruesandora/teritori-testnet
# dorianim/money-balancer
# WuDuShanCheng/front-show
# tomriddle77/Hacktober22
# TylerMcCraw/compose-creations
# axic/evm.elf
# editso/gungnir
# fusionhuh/deskimg
# vnsmoreira/get-route
# kshitij12345/torchnnprofiler
# ergrelet/cpplumber
# borakasmer/fuel
# TheOfficialFloW/Presentations
# ekoby/mqziti
# nyph-infosec/daggerboard
# oslabs-beta/iris
# oslabs-beta/franzView
# staltz/ttosa
# shellward/StablenderDiffusion
# sheepla/longgopher
# rustcc/2022RustChinaCnf-ppts
# Crunchyman-ralph/shopify-app-node-monorepo-express-vite
# forbearing/k8s
# vueschool/vuejs-forge-the-project
# ericpd/mr.wifibrute
# gamename/raspberry-pi-iot-cat-doorbell
# eliben/go-sudoku
# Ramilito/kubediff
# WesleyHsieh0806/Downstair-Battle
# kokonior/Swift-Projects
# TencentARC/RepSR
# AkhilSharma90/node-ecommerce-V2
# gwenneg/flight-tracker-demo
# AnaralahBelore223/marcos-martial-law-library
# tts-tutorial/icassp2022
# jbkunst/klassets
# mllamazares/STRIDE-vs-ASVS
# first-phoenix/PlacementResources_by_Swaraj
# BexTuychiev/tricking-data-science
# ruesandora/CW20-ICS20-Smart-Contract
# GraphicDThanh/danang-cuisine
# oslabs-beta/parroteer
# mrtc0/seccamp-2022
# shuo-china/shuo-ui
# laisfrigerio/ja-escalou-seu-time-no-cartola-hoje
# matthewcieplak/er-99
# mintrocket/MintPermissions
# Sorangon/Level-Up-Sketch-Open-Project
# dontpanicdao/starknet-burner
# ardiri/palmos-liberty
# R0X4R/Agnee
# coolbutuseless/isocubes
# microsoft/Build2022-AI-examples
# laisfrigerio/copy-emoji-to-clipboard
# MDAnalysis/WorkshopMDMLEdinburgh2022
# instadeepai/catx
# storopoli/Julia-Workshop
# ultramsg/vbnet-whatsapp-chatbot
# blackjax-devs/sampling-book

# %%
print(repo_name)
spec_repo_url=requests.get(f"https://api.github.com/repos/{repo_name}/commits?per_page=1&page=1",headers=headers)
headers = spec_repo_url.headers
# # pprint(headers['Link'])
pprint(int(headers['Link'].split('&page=')[-1].split(';')[0].split('>')[0]))
# Out:
# blackjax-devs/sampling-book
# 34

# %%
headers = spec_repo_url.headers
pprint(headers['Link'])
pprint(int(headers['Link'].split('&page=')[-1].split(';')[0].split('>')[0]))
# Out:
# ('<https://api.github.com/repositories/581039832/commits?per_page=1&page=2>; '
#  'rel="next", '
#  '<https://api.github.com/repositories/581039832/commits?per_page=1&page=34>; '
#  'rel="last"')
# 34
